# %%
# !pip install -q streamlit pyngrok
# !pip install -q qdrant-client pandas numpy sentence-transformers
# !pip install -q transformers torch bitsandbytes>=0.46.1 accelerate
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 81.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 110.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.3/337.3 kB 9.2 MB/s eta 0:00:00

# %%
import os
import time
from pyngrok import ngrok

PROJECT_PATH = ''
APP_PATH = f'{PROJECT_PATH}/app.py'
PORT = 8501

# Clean up
print(" Cleaning up...")
# !pkill -9 streamlit
# !sleep 3

# Start Streamlit in background
print(f" Starting Streamlit from: {APP_PATH}")
os.chdir(PROJECT_PATH)

# !nohup streamlit run {APP_PATH} \\
    --server.port {PORT} \\
    --server.address 0.0.0.0 \\
    --server.headless true \\
    > /content/streamlit.log 2>&1 &


print("\n Creating tunnel...")
ngrok.set_auth_token("XXXXXX")
public_url = ngrok.connect(PORT)

print("\n" + "=" * 70)
print(f" Public URL: {public_url}")
